# %%
import xarray as xr

# %%
# !ls ../era5/*.nc
# Out:
# ../era5/download.nc
# ../era5/era5-nordics-ecacdd.nc
# ../era5/era5-nordics-ecacfd.nc
# ../era5/era5-nordics-ecacsu.nc
# ../era5/era5-nordics-ecacwd.nc
# ../era5/era5-nordics-ecafd.nc
# ../era5/era5-nordics-ecahd.nc
# ../era5/era5-nordics-ecaid.nc
# ../era5/era5-nordics-ecapd.nc
# ../era5/era5-nordics-ecarr1.nc
# ../era5/era5-nordics-ecarx1day.nc
# ../era5/era5-nordics-ecarx5day.nc
# ../era5/era5-nordics-ecasdii.nc
# ../era5/era5-nordics-ecasu.nc
# ../era5/era5-nordics-frost-days.nc
# ../era5/era5-nordics-precipitation-2000-01.nc
# ../era5/era5-nordics-precipitation-2000-02.nc
# ../era5/era5-nordics-precipitation-2000-03.nc
# ../era5/era5-nordics-precipitation-2000-04.nc
# ../era5/era5-nordics-precipitation-2000-05.nc
# ../era5/era5-nordics-precipitation-2000-06.nc
# ../era5/era5-nordics-precipitation-2000-07.nc
# ../era5/era5-nordics-precipitation-2000-08.nc
# ../era5/era5-nordics-precipitation-2000-09.nc
# ../era5/era5-nordics-precipitation-2000-10.nc
# ...

# %%
ds_t2m = xr.open_dataset('../era5/era5-nordics-temperature-2000-01.nc')

# %%
ds_t2m
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 73, longitude: 111, time: 744)
# Coordinates:
#   * longitude  (longitude) float32 4.5 4.75 5.0 5.25 ... 31.25 31.5 31.75 32.0
#   * latitude   (latitude) float32 71.5 71.25 71.0 70.75 ... 54.0 53.75 53.5
#   * time       (time) datetime64[ns] 2000-01-01 ... 2000-01-31T23:00:00
# Data variables:
#     d2m        (time, latitude, longitude) float32 ...
#     t2m        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2018-11-16 09:49:48 GMT by grib_to_netcdf-2.7.0: /opt/ecmwf...

# %%
ds_t2m.t2m.where(ds_t2m.longitude > 10 & ds_t2m.longitude < 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-f29d3d849a7e> in <module>
# ----> 1 ds_t2m.t2m.where(ds_t2m.longitude > 10 & ds_t2m.longitude < 20)
#
# ~/dev/cc/sandbox-fabio/python-notebooks/env/lib/python3.7/site-packages/xarray/core/dataarray.py in func(self, other)
#    1971             variable = (f(self.variable, other_variable)
#    1972                         if not reflexive
# -> 1973                         else f(other_variable, self.variable))
#    1974             coords = self.coords._merge_raw(other_coords)
#    1975             name = self._result_name(other)
#
# ~/dev/cc/sandbox-fabio/python-notebooks/env/lib/python3.7/site-packages/xarray/core/variable.py in func(self, other)
#    1673                 new_data = (f(self_data, other_data)
#    1674                             if not reflexive
# ...

# %%
ds_t2m.loc[dict(longitude=slice(7., 11.))].values
# Out:
# <bound method Mapping.values of <xarray.Dataset>
# Dimensions:    (latitude: 73, longitude: 17, time: 744)
# Coordinates:
#   * longitude  (longitude) float32 7.0 7.25 7.5 7.75 ... 10.25 10.5 10.75 11.0
#   * latitude   (latitude) float32 71.5 71.25 71.0 70.75 ... 54.0 53.75 53.5
#   * time       (time) datetime64[ns] 2000-01-01 ... 2000-01-31T23:00:00
# Data variables:
#     d2m        (time, latitude, longitude) float32 ...
#     t2m        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2018-11-16 09:49:48 GMT by grib_to_netcdf-2.7.0: /opt/ecmwf...>
