# %%
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from glob import glob
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

from tqdm import tqdm

# %%
ds_p = xr.open_dataset("/data-temp/era5-nordics-precipitation_ymon.nc")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-a2865956ff37> in <module>
# ----> 1 ds_p = xr.open_dataset("/data-temp/era5-nordics-precipitation_ymon.nc")
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, autoclose, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime)
#     392
#     393     with close_on_error(store):
# --> 394         ds = maybe_decode_store(store)
#     395
#     396     # Ensure source filename always stored in dataset object (GH issue #2550)
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/backends/api.py in maybe_decode_store(store, lock)
#     322             store, mask_and_scale=mask_and_scale, decode_times=decode_times,
#     323             concat_characters=concat_characters, decode_coords=decode_coords,
# --> 324             drop_variables=drop_variables, use_cftime=use_cftime)
#     325
#     326         _protect_dataset_variables_inplace(ds, cache)
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/conventions.py in decode_cf(obj, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime)
#     478         vars, attrs, concat_characters, mask_and_scale, decode_times,
#     479         decode_coords, drop_variables=drop_variables, use_cftime=use_cftime)
# --> 480     ds = Dataset(vars, attrs=attrs)
#     481     ds = ds.set_coords(coord_names.union(extra_coords).intersection(vars))
#     482     ds._file_obj = file_obj
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/core/dataset.py in __init__(self, data_vars, coords, attrs, compat)
#     381             coords = {}
#     382         if data_vars is not None or coords is not None:
# --> 383             self._set_init_vars_and_dims(data_vars, coords, compat)
#     384
#     385         # TODO(shoyer): expose indexes as a public argument in __init__
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/core/dataset.py in _set_init_vars_and_dims(self, data_vars, coords, compat)
#     403
#     404         variables, coord_names, dims = merge_data_and_coords(
# --> 405             data_vars, coords, compat=compat)
#     406
#     407         self._variables = variables
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/core/merge.py in merge_data_and_coords(data, coords, compat, join)
#     375     indexes = dict(extract_indexes(coords))
#     376     return merge_core(objs, compat, join, explicit_coords=explicit_coords,
# --> 377                       indexes=indexes)
#     378
#     379
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/core/merge.py in merge_core(objs, compat, join, priority_arg, explicit_coords, indexes)
#     444     coerced = coerce_pandas_values(objs)
#     445     aligned = deep_align(coerced, join=join, copy=False, indexes=indexes)
# --> 446     expanded = expand_variable_dicts(aligned)
#     447
#     448     coord_names, noncoord_names = determine_coords(coerced)
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/core/merge.py in expand_variable_dicts(list_of_variable_dicts)
#     220                 var_dicts.append(coords)
#     221
# --> 222             var = as_variable(var, name=name)
#     223             sanitized_vars[name] = var
#     224
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/core/variable.py in as_variable(obj, name)
#     115                 'conflict with the coordinates used to label '
#     116                 'dimensions.' % (name, obj.dims))
# --> 117         obj = obj.to_index_variable()
#     118
#     119     return obj
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/core/variable.py in to_index_variable(self)
#     406         """Return this variable as an xarray.IndexVariable"""
#     407         return IndexVariable(self.dims, self._data, self._attrs,
# --> 408                              encoding=self._encoding, fastpath=True)
#     409
#     410     to_coord = utils.alias(to_index_variable, 'to_coord')
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/core/variable.py in __init__(self, dims, data, attrs, encoding, fastpath)
#    1823         # Unlike in Variable, always eagerly load values into memory
#    1824         if not isinstance(self._data, PandasIndexAdapter):
# -> 1825             self._data = PandasIndexAdapter(self._data)
#    1826
#    1827     def load(self):
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/core/indexing.py in __init__(self, array, dtype)
#    1217
#    1218     def __init__(self, array, dtype=None):
# -> 1219         self.array = utils.safe_cast_to_index(array)
#    1220         if dtype is None:
#    1221             if isinstance(array, pd.PeriodIndex):
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/core/utils.py in safe_cast_to_index(array)
#      76         if hasattr(array, 'dtype') and array.dtype.kind == 'O':
#      77             kwargs['dtype'] = object
# ---> 78         index = pd.Index(np.asarray(array), **kwargs)
#      79     return _maybe_cast_to_cftimeindex(index)
#      80
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     508     def __array__(self, dtype=None):
#     509         array = as_indexable(self.array)
# --> 510         return np.asarray(array[self.key], dtype=None)
#     511
#     512     def transpose(self, order):
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/coding/variables.py in __array__(self, dtype)
#      66
#      67     def __array__(self, dtype=None):
# ---> 68         return self.func(self.array)
#      69
#      70     def __repr__(self):
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/coding/times.py in decode_cf_datetime(num_dates, units, calendar, use_cftime)
#     174         try:
#     175             dates = _decode_datetime_with_pandas(flat_num_dates, units,
# --> 176                                                  calendar)
#     177         except (OutOfBoundsDatetime, OverflowError):
#     178             dates = _decode_datetime_with_cftime(
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/xarray/coding/times.py in _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     139         warnings.filterwarnings('ignore', 'invalid value encountered',
#     140                                 RuntimeWarning)
# --> 141         pd.to_timedelta(flat_num_dates.min(), delta) + ref_date
#     142         pd.to_timedelta(flat_num_dates.max(), delta) + ref_date
#     143
#
# ~/linda-forest-climate/notebooks/env/lib/python3.6/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims, initial)
#      30 def _amin(a, axis=None, out=None, keepdims=False,
#      31           initial=_NoValue):
# ---> 32     return umr_minimum(a, axis, None, out, keepdims, initial)
#      33
#      34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
ds_p
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 73, longitude: 111, time: 1)
# Coordinates:
#   * latitude   (latitude) float32 71.5 71.25 71.0 70.75 ... 54.0 53.75 53.5
#   * longitude  (longitude) float32 4.5 4.75 5.0 5.25 ... 31.25 31.5 31.75 32.0
#   * time       (time) datetime64[ns] 2018-01-31T23:00:00
# Data variables:
#     tp         (time, latitude, longitude) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version ?? (http://mpimet.mpg.de/cdi)
#     Conventions:  CF-1.6
#     history:      Thu Nov 29 22:19:52 2018: ncks -O -d time,0 ../era5/era5-no...
#     CDO:          Climate Data Operators version 1.9.3 (http://mpimet.mpg.de/...
#     NCO:          4.7.2

# %%
ds_p.tp[0].plot()

# %%
ds_t_avg = xr.open_mfdataset("../era5/era5-nordics-t2m_ymon.nc")
ds_t_std = xr.open_mfdataset("../era5/era5-nordics-t2m_ymonstd.nc")

# %%
ds_t_avg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-721101aafd26> in <module>
# ----> 1 ds_t_avg
#
# NameError: name 'ds_t_avg' is not defined

# %%
lons, lats = np.meshgrid(ds_p.longitude, ds_p.latitude)

# %%
lons
# Out:
# array([[ 4.5 ,  4.75,  5.  , ..., 31.5 , 31.75, 32.  ],
#        [ 4.5 ,  4.75,  5.  , ..., 31.5 , 31.75, 32.  ],
#        [ 4.5 ,  4.75,  5.  , ..., 31.5 , 31.75, 32.  ],
#        ...,
#        [ 4.5 ,  4.75,  5.  , ..., 31.5 , 31.75, 32.  ],
#        [ 4.5 ,  4.75,  5.  , ..., 31.5 , 31.75, 32.  ],
#        [ 4.5 ,  4.75,  5.  , ..., 31.5 , 31.75, 32.  ]], dtype=float32)

# %%
psr = xr.open_dataset("pine_spruce.nc")

# %%
psr.volume.plot()

# %%
df = pd.DataFrame()

# %%
data = {
    "ratio": psr.volume.values.ravel()
}

# %%
data.keys()
# Out:
# dict_keys(['ratio'])

# %%
for m in range(0, 12):
    data["p%02d" % (m + 1)] = ds_p.tp[m].values.ravel()
    data["tavg%02d" % (m + 1)] = ds_t_avg.t2m[m].values.ravel()
    data["tstd%02d" % (m + 1)] = ds_t_std.t2m[m].values.ravel()
    #data["lat"] = lats.ravel()
    #data["lon"] = lons.ravel()

# %%
df = pd.DataFrame(data)

# %%
df.dropna(inplace=True)

# %%
df = df[df["ratio"] > 0]

# %%
df.columns[1:]
# Out:
# Index(['p01', 'tavg01', 'tstd01', 'p02', 'tavg02', 'tstd02', 'p03', 'tavg03',
#        'tstd03', 'p04', 'tavg04', 'tstd04', 'p05', 'tavg05', 'tstd05', 'p06',
#        'tavg06', 'tstd06', 'p07', 'tavg07', 'tstd07', 'p08', 'tavg08',
#        'tstd08', 'p09', 'tavg09', 'tstd09', 'p10', 'tavg10', 'tstd10', 'p11',
#        'tavg11', 'tstd11', 'p12', 'tavg12', 'tstd12', 'lat', 'lon'],
#       dtype='object')

# %%
rf = RandomForestRegressor(n_estimators=500, max_depth=15)

# %%
X_train, X_test, y_train, y_test = train_test_split(df[df.columns[1:]], df["ratio"])

# %%
X_train
# Out:
#               p01     tavg01    tstd01          p02     tavg02    tstd02  \
# 2613  2841.042969 -10.388478  7.557813   719.565857  -9.617783  7.833101
# 3494  2893.817383  -7.991909  6.687978   658.695374  -7.532806  7.018993
# 2273  3278.997803 -11.469535  7.476870  1144.126465 -10.654109  7.491045
# 5049  2785.325684  -2.618880  5.066350   650.930847  -2.606457  5.030917
# 4916  3277.944092  -5.650849  6.644724   973.805115  -4.925607  5.778079
# 3286  2999.731445  -4.487235  5.222780   785.772461  -6.079182  5.834244
# 5374  3073.004639  -2.621937  5.668977   816.197083  -2.474729  5.272104
# 2733  2897.093994  -8.065157  7.072434   696.041687  -8.210560  7.300220
# 2723  2862.704102 -10.109963  7.295352   720.921875  -9.439564  7.627171
# 2828  2964.980713  -9.470495  7.381667   820.152283  -8.777191  7.542365
# 5689  3579.301025  -0.576661  5.079129  1145.678223  -0.827979  4.710821
# 4269  2940.245117  -3.170588  4.759675   671.336243  -3.299371  4.901459
# 6262  2943.188965  -1.557312  4.997420   749.234009  -1.424801  4.853815
# 3490  2903.710205  -7.676190  6.967997   680.017212  -7.081426  7.095004
# 3597  2939.545898  -6.947397  6.596236   700.651672  -6.499161  6.810483
# 4922  3260.444092  -5.166470  6.003772   935.010315  -4.793101  5.557531
# 3932  2857.166260  -7.150472  6.952889   611.030151  -6.485607  6.926212
# 5697  3155.591064  -0.319818  3.965741   878.514038  -1.112227  3.881661
predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.04592075988287657

# %%
r2_score(y_test, y_pred)
# Out:
# 0.20732489603015347

# %%
plt.scatter(y_test, y_pred)

# %%
df_results = pd.DataFrame({"observed": y_test, "predicted": y_pred},)

# %%
df_results
# Out:
#       observed  predicted
# 2294  0.558532   0.687519
# 3707  0.904518   0.405449
# 3611  0.710525   0.506246
# 3604  0.611634   0.397568
# 2182  0.160218   0.796799
# 2400  0.984061   0.593915
# 6583  0.186109   0.280092
# 2932  0.353989   0.104946
# 2393  0.788891   0.639169
# 5370  0.445707   0.413882
# 6037  0.533163   0.492867
# 7140  0.306908   0.540120
# 2832  0.794258   0.693967
# 2279  0.696030   0.608999
# 3930  0.555754   0.412131
# 4594  0.692416   0.578752
# 6476  0.502442   0.407541
# 5249  0.458237   0.305769
# 1847  0.540596   0.657102
# 4712  0.584756   0.590106
# 3589  0.124716   0.255778
# 5471  0.447055   0.392204
# 5367  0.324202   0.406616
# 2948  0.877960   0.703018
# 2952  0.609253   0.781295
# 3375  0.346188   0.476707
# 4809  0.841436   0.595111
# 4367  0.476266   0.760290
# 5579  0.717273   0.300738
# 3827  0.142771   0.328656
# ...        ...        ...
# 3378  0.525911   0.505691
# 4710  0.411961   0.594859
# 4805  0.689288   0.514068
# 2387  0.934125   0.478649
# 2055  0.316732   0.439313
# 3062  0.641568   0.791588
# 5371  0.438681   0.405100
# 4368  0.901695   0.713286
# 5926  0.486988   0.471400
# 6360  0.200560   0.305397
# 4146  0.370944   0.687996
# 2728  0.915016   0.781458
# 2497  0.446596   0.622357
# 2185  0.434641   0.713643
# 2721  0.173327   0.741145
# 5362  0.397295   0.286298
# 6147  0.287332   0.512315
# 4366  0.473039   0.740984
# 4695  0.301709   0.532660
# 5481  0.950114   0.568451
# 1738  0.841541   0.801220
# 2065  0.870186   0.644730
# 5153  0.630939   0.546297
# 4152  0.794695   0.481790
# 3601  0.380697   0.496298
# 5029  0.550210   0.482562
# 2176  0.264235   0.729010
# 2730  0.856563   0.754551
# 5933  1.000000   0.852912
# 6023  0.523719   0.525102
#
# [272 rows x 2 columns]

# %%
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance',                                                                 ascending=False)

# %%
feature_importances
# Out:
#         importance
# lon       0.063647
# p03       0.060746
# p02       0.054254
# p12       0.043671
# p01       0.043576
# p10       0.043214
# tavg04    0.038736
# p07       0.036570
# tavg05    0.035967
# p06       0.031905
# tavg09    0.030563
# tstd10    0.029220
# p04       0.028360
# tavg07    0.028213
# tavg08    0.026588
# tavg06    0.026453
# p08       0.025929
# p05       0.024821
# p09       0.023929
# tavg03    0.023135
# tstd09    0.022397
# p11       0.021827
# tavg12    0.019472
# tstd05    0.017742
# tstd12    0.016929
# tstd11    0.016073
# tstd08    0.016063
# tstd04    0.015884
# tavg11    0.015190
# tstd02    0.015177
# tstd01    0.014514
# tstd06    0.014486
# lat       0.014079
# tavg10    0.013723
# tstd03    0.012746
# tstd07    0.012678
# tavg01    0.011456
# tavg02    0.010067

# %%
plt.figure(figsize=(12,8))
plt.bar(feature_importances.index, feature_importances["importance"])
plt.xticks(rotation=90)
plt.show()
